# %%
 # Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %%
#Config information and query URL
base_url = "https://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={api_key}&units={units}&q="

# %%
#lists to hold response info
temp = [] #weather_response['main']['temp']
latitude = [] #weather_response['coord']['lat']
humidity = [] #weather_response['main']['humidity']
cloudiness = [] #weather_response['clouds']['all']
wind_speed = [] #weather_response['wind']['speed']
city_list = [] #weather_response['name']
longitude = [] #weather_response['coord']['lon']

# %%
#loop and retrieve data for cities
for city in cities:
    weather_response = requests.get(query_url + city).json()
    
    try:
        print(f"Processing City: {city}")
        temp.append(weather_response['main']['temp'])
        latitude.append(weather_response['coord']['lat'])
        longitude.append(weather_response['coord']['lon'])
        humidity.append(weather_response['main']['humidity'])
        cloudiness.append(weather_response['clouds']['all'])
        wind_speed.append(weather_response['wind']['speed'])
        city_list.append(city)
    except KeyError:
        print: "City not found.. skipping"
# Out:
# Processing City: yablonovo
# Processing City: rikitea
# Processing City: mount gambier
# Processing City: lasa
# Processing City: port alfred
# Processing City: butaritari
# Processing City: ballina
# Processing City: caravelas
# Processing City: hermanus
# Processing City: zhanaozen
# Processing City: iki-burul
# Processing City: pevek
# Processing City: hilo
# Processing City: ouadda
# Processing City: pangoa
# Processing City: baoning
# Processing City: vaini
# Processing City: vuktyl
# Processing City: punta arenas
# Processing City: san cristobal
# Processing City: esperance
# Processing City: ushuaia
# Processing City: jamestown
# Processing City: brae
# Processing City: atuona
# Processing City: belmonte
# Processing City: kungurtug
# Processing City: katsuura
# Processing City: emerald
# Processing City: bihac
# Processing City: tezu
# Processing City: cherskiy
# Processing City: mataura
# Processing City: bethel
# Processing City: saint-pierre
# Processing City: carnarvon
# Processing City: illoqqortoormiut
# Processing City: khatanga
# Processing City: pochutla
# Processing City: belushya guba
# Processing City: college
# Processing City: ilulissat
# Processing City: chokurdakh
# Processing City: cape town
# Processing City: irbil
# Processing City: barrow
# Processing City: virginia beach
# Processing City: uglich
# Processing City: mount isa
# Processing City: alofi
# Processing City: coihaique
# Processing City: liku
# Processing City: barentsburg
# Processing City: piacabucu
# Processing City: tuatapere
# Processing City: upernavik
# Processing City: mayo
# Processing City: san patricio
# Processing City: karratha
# Processing City: smolenka
# Processing City: carutapera
# Processing City: hobart
# Processing City: vertientes
# Processing City: lavrentiya
# Processing City: kapaa
# Processing City: hithadhoo
# Processing City: kahului
# Processing City: albany
# Processing City: bluff
# Processing City: victoria
# Processing City: tasiilaq
# Processing City: saint george
# Processing City: sabang
# Processing City: mae sai
# Processing City: east london
# Processing City: sokoni
# Processing City: enterprise
# Processing City: saint-philippe
# Processing City: hasaki
# Processing City: lolua
# Processing City: pangnirtung
# Processing City: isla vista
# Processing City: port macquarie
# Processing City: doctor pedro p. pena
# Processing City: felanitx
# Processing City: norman wells
# Processing City: hailar
# Processing City: ostrovnoy
# Processing City: lebu
# Processing City: taolanaro
# Processing City: taltal
# Processing City: parrita
# Processing City: saskylakh
# Processing City: ponta do sol
# Processing City: zhezkazgan
# Processing City: castro alves
# Processing City: leningradskiy
# Processing City: nagar karnul
# Processing City: joconal
# Processing City: georgetown
# Processing City: lompoc
# Processing City: port elizabeth
# Processing City: bengkulu
# Processing City: asau
# Processing City: hovd
# Processing City: cabrero
# Processing City: khasan
# Processing City: sortland
# Processing City: colares
# Processing City: verkhnevilyuysk
# Processing City: plainfield
# Processing City: mys shmidta
# Processing City: ribeira grande
# Processing City: porto torres
# Processing City: shingu
# Processing City: nizwa
# Processing City: havre-saint-pierre
# Processing City: bredasdorp
# Processing City: charters towers
# Processing City: qaanaaq
# Processing City: castro
# Processing City: challans
# Processing City: sorland
# Processing City: luanda
# Processing City: itzehoe
# Processing City: puri
# Processing City: bestobe
# Processing City: yeppoon
# Processing City: jalu
# Processing City: yumen
# Processing City: lac du bonnet
# Processing City: kushmurun
# Processing City: kaitangata
# Processing City: altar
# Processing City: floro
# Processing City: nueve de julio
# Processing City: puerto ayora
# Processing City: hun
# Processing City: bantry
# Processing City: roma
# Processing City: bandarbeyla
# Processing City: kijang
# Processing City: provideniya
# Processing City: ohara
# Processing City: kavieng
# Processing City: busselton
# Processing City: itatskiy
# Processing City: nizhneivkino
# Processing City: boende
# Processing City: nome
# Processing City: flinders
# Processing City: tiksi
# Processing City: nikolskoye
# Processing City: kodiak
# Processing City: yazman
# Processing City: saldanha
# Processing City: ixtapa
# Processing City: sunland park
# Processing City: bilma
# Processing City: talnakh
# Processing City: maraba
# Processing City: ulladulla
# Processing City: kaeo
# Processing City: bend
# Processing City: opichen
# Processing City: asosa
# Processing City: tuktoyaktuk
# Processing City: mataram
# Processing City: blonduos
# Processing City: kantunilkin
# Processing City: harper
# Processing City: namibe
# Processing City: mehamn
# Processing City: amderma
# Processing City: alugan
# Processing City: novikovo
# Processing City: palabuhanratu
# Processing City: kropotkin
# Processing City: vagay
# Processing City: broken hill
# Processing City: bambous virieux
# Processing City: sept-iles
# Processing City: arraial do cabo
# Processing City: tumannyy
# Processing City: tharad
# Processing City: iqaluit
# Processing City: lorengau
# Processing City: natchitoches
# Processing City: grahamstown
# Processing City: ratnagiri
# Processing City: blois
# Processing City: nishihara
# Processing City: methven
# Processing City: tilichiki
# Processing City: comodoro rivadavia
# Processing City: beroroha
# Processing City: pontianak
# Processing City: vostok
# Processing City: aflu
# Processing City: te anau
# Processing City: airai
# Processing City: poronaysk
# Processing City: nikolayevsk-na-amure
# Processing City: geraldton
# Processing City: avarua
# Processing City: xinglongshan
# Processing City: vestmannaeyjar
# Processing City: ancud
# Processing City: ahumada
# Processing City: warqla
# Processing City: tabou
# Processing City: half moon bay
# Processing City: maniitsoq
# Processing City: lagoa
# Processing City: boyabat
# Processing City: banda aceh
# Processing City: collie
# Processing City: tura
# Processing City: nizhneyansk
# Processing City: praia da vitoria
# Processing City: puerto escondido
# Processing City: kusye-aleksandrovskiy
# Processing City: vanavara
# Processing City: nanortalik
# Processing City: waipawa
# Processing City: tondano
# Processing City: muros
# Processing City: boca do acre
# Processing City: port-cartier
# Processing City: lenki
# Processing City: rawson
# Processing City: olafsvik
# Processing City: del rio
# Processing City: mayumba
# Processing City: zwedru
# Processing City: rajanpur
# Processing City: quatre cocos
# Processing City: kamaishi
# Processing City: severo-kurilsk
# Processing City: poum
# Processing City: maceio
# Processing City: karaul
# Processing City: camargo
# Processing City: clyde river
# Processing City: grand river south east
# Processing City: daru
# Processing City: teya
# Processing City: la crosse
# Processing City: codrington
# Processing City: antofagasta
# Processing City: lumby
# Processing City: pervomayskoye
# Processing City: cidreira
# Processing City: laguna
# Processing City: manokwari
# Processing City: constitucion
# Processing City: vaitupu
# Processing City: dikson
# Processing City: faanui
# Processing City: coquimbo
# Processing City: sentyabrskiy
# Processing City: gemena
# Processing City: garowe
# Processing City: narsaq
# Processing City: torbay
# Processing City: lahad datu
# Processing City: tomohon
# Processing City: igarka
# Processing City: san quintin
# Processing City: charyshskoye
# Processing City: hobyo
# Processing City: yellowknife
# Processing City: zhigansk
# Processing City: lafia
# Processing City: thompson
# Processing City: colac
# Processing City: tsihombe
# Processing City: haines junction
# Processing City: cozumel
# Processing City: rorvik
# Processing City: nadym
# Processing City: sinjai
# Processing City: port moresby
# Processing City: toftir
# Processing City: sao joao da barra
# Processing City: salalah
# Processing City: louisbourg
# Processing City: tawkar
# Processing City: las lomas
# Processing City: vardo
# Processing City: huarmey
# Processing City: atasu
# Processing City: fortuna
# Processing City: bolshaya atnya
# Processing City: ngukurr
# Processing City: paradwip
# Processing City: sur
# Processing City: cabo san lucas
# Processing City: vila franca do campo
# Processing City: beira
# Processing City: sisimiut
# Processing City: marawi
# Processing City: korla
# Processing City: tahoua
# Processing City: manaus
# Processing City: kiruna
# Processing City: ahipara
# Processing City: grindavik
# Processing City: sao felix do xingu
# Processing City: batemans bay
# Processing City: klaksvik
# Processing City: vrangel
# Processing City: kruisfontein
# Processing City: halifax
# Processing City: the valley
# Processing City: nichinan
# Processing City: new norfolk
# Processing City: nikel
# Processing City: kiunga
# Processing City: watsa
# Processing City: atambua
# Processing City: wampusirpi
# Processing City: mullaitivu
# Processing City: kalmunai
# Processing City: aba
# Processing City: satitoa
# Processing City: luderitz
# Processing City: souflion
# Processing City: cleveland
# Processing City: inhambane
# Processing City: colquiri
# Processing City: mar del plata
# Processing City: rio grande
# Processing City: los llanos de aridane
# Processing City: meyungs
# Processing City: padang
# Processing City: homer
# Processing City: toliary
# Processing City: guerrero negro
# Processing City: shelabolikha
# Processing City: hagere hiywet
# Processing City: lucapa
# Processing City: manaure
# Processing City: riyadh
# Processing City: lata
# Processing City: athabasca
# Processing City: vreed en hoop
# Processing City: payo
# Processing City: luancheng
# Processing City: ossora
# Processing City: piryion
# Processing City: aksu
# Processing City: melo
# Processing City: talcahuano
# Processing City: khandyga
# Processing City: mahebourg
# Processing City: kidal
# Processing City: xambioa
# Processing City: samalaeulu
# Processing City: puerto penasco
# Processing City: altay
# Processing City: camacha
# Processing City: labuhan
# Processing City: mbandaka
# Processing City: agadir
# Processing City: esil
# Processing City: ayan
# Processing City: iralaya
# Processing City: saint-augustin
# Processing City: guajara-mirim
# Processing City: isangel
# Processing City: gulshat
# Processing City: oskemen
# Processing City: hamilton
# Processing City: faya
# Processing City: katsuyama
# Processing City: pirassununga
# Processing City: mbanza-ngungu
# Processing City: likasi
# Processing City: wanaka
# Processing City: shakawe
# Processing City: waw
# Processing City: itarema
# Processing City: granville
# Processing City: dudinka
# Processing City: rio gallegos
# Processing City: jonkoping
# Processing City: lityn
# Processing City: hohhot
# Processing City: chuy
# Processing City: redding
# Processing City: killybegs
# Processing City: ust-kamchatsk
# Processing City: port blair
# Processing City: karlstadt
# Processing City: taoudenni
# Processing City: aklavik
# Processing City: sinnamary
# Processing City: bereda
# Processing City: sawakin
# Processing City: oktyabrskiy
# Processing City: hay river
# Processing City: karksi-nuia
# Processing City: kandalaksha
# Processing City: haapiti
# Processing City: omboue
# Processing City: qalyub
# Processing City: kifri
# Processing City: bambanglipuro
# Processing City: tanout
# Processing City: qasigiannguit
# Processing City: mulege
# Processing City: butembo
# Processing City: umzimvubu
# Processing City: kristinehamn
# Processing City: sechura
# Processing City: ozieri
# Processing City: bac lieu
# Processing City: sayyan
# Processing City: aswan
# Processing City: mackay
# Processing City: chulman
# Processing City: tecolutilla
# Processing City: puerto colombia
# Processing City: treinta y tres
# Processing City: polunochnoye
# Processing City: yulara
# Processing City: nemuro
# Processing City: acajutla
# Processing City: samusu
# Processing City: chake chake
# Processing City: meulaboh
# Processing City: tartagal
# Processing City: mana
# Processing City: port-gentil
# Processing City: henties bay
# Processing City: yerbogachen
# Processing City: maldonado
# Processing City: cairns
# Processing City: murgab
# Processing City: floresta
# Processing City: ures
# Processing City: tidore
# Processing City: balabac
# Processing City: port hedland
# Processing City: camabatela
# Processing City: bacuit
# Processing City: orangeburg
# Processing City: tupik
# Processing City: amapa
# Processing City: izhma
# Processing City: liniere
# Processing City: touros
# Processing City: narimanov
# Processing City: rocha
# Processing City: hadejia
# Processing City: iberia
# Processing City: atar
# Processing City: grand centre
# Processing City: eyl
# Processing City: aljezur
# Processing City: gao
# Processing City: hunchun
# Processing City: gorgan
# Processing City: pueblo nuevo
# Processing City: basco
# Processing City: plettenberg bay
# Processing City: belchatow
# Processing City: paita
# Processing City: margate
# Processing City: bosaso
# Processing City: lazaro cardenas
# Processing City: shelburne
# Processing City: turayf
# Processing City: krasnovishersk
# Processing City: setermoen
# Processing City: port lincoln
# Processing City: friesach
# Processing City: makakilo city
# Processing City: gorno-chuyskiy
# Processing City: teguise
# Processing City: beringovskiy
# Processing City: tessalit
# Processing City: kamenskoye
# Processing City: takaka
# Processing City: nantucket
# Processing City: khandagayty
# Processing City: tautira
# Processing City: avera
# Processing City: vestbjerg
# Processing City: johnshaven
# Processing City: broome
# Processing City: longyearbyen
# Processing City: coxim
# Processing City: sembe
# Processing City: naze
# Processing City: arlit
# Processing City: horasan
# Processing City: ust-kuyga
# Processing City: saint-leu
# Processing City: corinto
# Processing City: morondava
# Processing City: sergeyevka
# Processing City: acapulco
# Processing City: shubarkuduk
# Processing City: sola
# Processing City: fos-sur-mer
# Processing City: shenjiamen
# Processing City: abu samrah
# Processing City: budogoshch
# Processing City: puerto baquerizo moreno
# Processing City: jonesboro
# Processing City: sibu
# Processing City: brookhaven
# Processing City: kavaratti
# Processing City: cayenne
# Processing City: semporna
# Processing City: qafsah
# Processing City: tieling
# Processing City: skiros
# Processing City: birao
# Processing City: landerneau
# Processing City: jojoima
# Processing City: hami
# Processing City: hirara
# Processing City: jawa
# Processing City: bara
# Processing City: champerico
# Processing City: tabarqah
# Processing City: mao
# Processing City: kyren
# Processing City: tocopilla
# Processing City: tonantins
# Processing City: santa isabel do rio negro
# Processing City: sitka
# Processing City: cabedelo
# Processing City: nioro
# Processing City: fairview
# Processing City: chagda
# Processing City: labytnangi
# Processing City: kieta
# Processing City: surt
# Processing City: sao filipe
# Processing City: conde
# Processing City: shimoda
# Processing City: dingle
# Processing City: bilibino
# Processing City: teknaf
# Processing City: nidzica
# Processing City: komsomolskiy
# Processing City: nouna
# Processing City: barra patuca
# Processing City: abbeville
# Processing City: rodrigues alves
# Processing City: manadhoo
# Processing City: soligalich
# Processing City: katangli
# Processing City: chapleau
# Processing City: roshchino
# Processing City: lagos de moreno
# Processing City: kuah
# Processing City: kita
# Processing City: yar-sale
# Processing City: suntar
# Processing City: ruston
# Processing City: casper
# Processing City: trifesti
# Processing City: monrovia
# Processing City: nouakchott
# Processing City: haverfordwest
# Processing City: mecca
# Processing City: taketa
# Processing City: kawana waters
# Processing City: uray
# Processing City: amli
# Processing City: tutoia
# Processing City: quelimane
# Processing City: mazagao
# Processing City: peniche
# Processing City: yuzhno-yeniseyskiy
# Processing City: north bend
# Processing City: porosozero
# Processing City: san andres
# Processing City: xuanhua
# Processing City: penzance
# Processing City: rosarito
# Processing City: husavik
# Processing City: bathsheba
# Processing City: ola
# Processing City: fairbanks
# Processing City: balaipungut
# Processing City: banjar
# Processing City: hambantota
# Processing City: moerai
# Processing City: kodinsk
# Processing City: fort nelson
# Processing City: gogrial
# Processing City: guarapari
# Processing City: teseney
# Processing City: santa helena de goias
# Processing City: sao miguel do araguaia
# Processing City: traverse city
# Processing City: pundaguitan
# Processing City: am timan
# Processing City: katherine
# Processing City: torrelavega
# Processing City: itaituba
# Processing City: yairipok

# %%
weather_df = pd.DataFrame({
    "City": city_list,
    "Temperature(F)": temp,
    "Latitude": latitude,
    "Longitude": longitude,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed
})
weather_df
# Out:
#               City  Temperature(F)  Latitude  Longitude  Humidity  Cloudiness  \
# 0        yablonovo           64.08   50.8523    37.3574        75          57
# 1          rikitea           74.03  -23.1203  -134.9692        80         100
# 2    mount gambier           54.21  -37.8333   140.7667        58         100
# 3             lasa           62.37   46.6166    10.7002        88           6
# 4      port alfred           60.19  -33.5906    26.8910        86          55
# ..             ...             ...       ...        ...       ...         ...
# 556       am timan           71.01   11.0297    20.2827        95         100
# 557      katherine           89.92  -14.4667   132.2667        15           0
# 558    torrelavega           68.76   43.3494    -4.0479        85           0
# 559       itaituba           82.56   -4.2761   -55.9836        78           0
# 560       yairipok           73.74   24.6667    94.0667        89         100
#
#      Wind Speed
# 0          6.33
# 1         17.22
# 2         13.42
# 3          1.74
# 4          5.01
# ..          ...
# 556       11.56
# 557       10.36
# 558        1.99
# 559        0.00
# 560        1.99
#
# [561 rows x 7 columns]

# %%
weather_df.to_csv('output_data\cities.csv')

# %%
#Latitude vs Temperature
plt.scatter(weather_df['Latitude'],weather_df['Temperature(F)'])
plt.title("City Latitude vs. Temperature(F)")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.savefig('output_data/fig1.png')
plt.show()
print("Code is analyzing the relationship between latitude and temperature. As latitude gets closer to 0, temperature increases.")
# Out:
# Code is analyzing the relationship between latitude and temperature. As latitude gets closer to 0, temperature increases.

# %%
#Latitude vs Humidity
plt.scatter(weather_df['Latitude'],weather_df['Humidity'])
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.savefig('output_data/fig2.png')
plt.show()
print("Code is analyzing the relationship between latitude and humidity. As latitude gets closer to 0, humidity tends to be at least above 40%, however latitudes higher and lower than 0 also have humidity above that value.")
# Out:
# Code is analyzing the relationship between latitude and humidity. As latitude gets closer to 0, humidity tends to be at least above 40%, however latitudes higher and lower than 0 also have humidity above that value.

# %%
#Latitude vs Cloudiness
plt.scatter(weather_df['Latitude'],weather_df['Cloudiness'])
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.savefig('output_data/fig3.png')
plt.show()
print("Code is analyzing latitude vs cloudiness, there is not a significant relationship between the two. ")
# Out:
# Code is analyzing latitude vs cloudiness, there is not a significant relationship between the two.

# %%
#Latitude vs Windspeed
plt.scatter(weather_df['Latitude'],weather_df['Wind Speed'])
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.savefig('output_data/fig4.png')
plt.show()
print("Code is analyzing latitude vs wind speed, there is not a significant relationship between the two. ")
# Out:
# Code is analyzing latitude vs wind speed, there is not a significant relationship between the two.

# %%
#Create northern and southern hemisphere dataframes
north_df = weather_df.loc[(weather_df['Latitude'] > 0),:]
south_df = weather_df.loc[(weather_df['Latitude'] < 0),:]

# %%
#Northern Hemisphere Latitude vs Temperature
plt.scatter(north_df['Latitude'],north_df['Temperature(F)'])
plt.title("Northern Hemisphere - City Latitude vs. Temperature(F)")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_df['Latitude'],north_df['Temperature(F)'])
regress_values = north_df['Latitude'] * slope + intercept
plt.plot(north_df['Latitude'], regress_values, "r-")
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.annotate(line_eq, (10,50))
plt.savefig('output_data/fig5.png')
plt.show()
print(f"The r-value is: {rvalue}")
print("As city latitude gets further from 0, temperature decreases.")
# Out:
# The r-value is: -0.7235835844483591
# As city latitude gets further from 0, temperature decreases.

# %%
#Southern Hemisphere Latitude vs Temperature
plt.scatter(south_df['Latitude'],south_df['Temperature(F)'])
plt.title("Southern Hemisphere - City Latitude vs. Temperature(F)")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_df['Latitude'],south_df['Temperature(F)'])
regress_values = south_df['Latitude'] * slope + intercept
plt.plot(south_df['Latitude'], regress_values, "r-")
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.annotate(line_eq, (-50,80))
plt.savefig('output_data/fig6.png')
plt.show()
print(f"The r-value is: {rvalue}")
print("As city latitude gets closer to 0, temperature increases.")
# Out:
# The r-value is: 0.8240191348720098
# As city latitude gets closer to 0, temperature increases.

# %%
#Northern Hemisphere Latitude vs Humidity
plt.scatter(north_df['Latitude'],north_df['Humidity'])
plt.title("Northern Hemisphere - City Latitude vs. Humidity")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_df['Latitude'],north_df['Humidity'])
regress_values = north_df['Latitude'] * slope + intercept
plt.plot(north_df['Latitude'], regress_values, "r-")
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.annotate(line_eq, (50,10))
plt.savefig('output_data/fig7.png')
plt.show()
print(f"The r-value is: {rvalue}")
print("As city latitude gets further from 0, humidity increases.")
# Out:
# The r-value is: 0.005951095610453289
# As city latitude gets further from 0, humidity increases.

# %%
#Southern Hemisphere Latitude vs Humidity
plt.scatter(south_df['Latitude'],south_df['Humidity'])
plt.title("Southern Hemisphere - City Latitude vs. Humidity")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_df['Latitude'],south_df['Humidity'])
regress_values = south_df['Latitude'] * slope + intercept
plt.plot(south_df['Latitude'], regress_values, "r-")
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.annotate(line_eq, (-50,20))
plt.savefig('output_data/fig8.png')
plt.show()
print(f"The r-value is: {rvalue}")
print("As city latitude gets closer 0, humidity increases.")
# Out:
# The r-value is: 0.13919785798204767
# As city latitude gets closer 0, humidity increases.

# %%
#Northern Hemisphere Latitude vs Cloudiness
plt.scatter(north_df['Latitude'],north_df['Cloudiness'])
plt.title("Northern Hemisphere - City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_df['Latitude'],north_df['Cloudiness'])
regress_values = north_df['Latitude'] * slope + intercept
plt.plot(north_df['Latitude'], regress_values, "r-")
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.annotate(line_eq, (-1,27))
plt.savefig('output_data/fig9.png')
plt.show()
print(f"The r-value is: {rvalue}")
print("As city latitude gets further from 0, cloudiness decreases.")
# Out:
# The r-value is: -0.036143337970667225
# As city latitude gets further from 0, cloudiness decreases.

# %%
#Southern Hemisphere Latitude vs Cloudiness
plt.scatter(south_df['Latitude'],south_df['Cloudiness'])
plt.title("Southern Hemisphere - City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_df['Latitude'],south_df['Cloudiness'])
regress_values = south_df['Latitude'] * slope + intercept
plt.plot(south_df['Latitude'], regress_values, "r-")
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.annotate(line_eq, (-55,20))
plt.savefig('output_data/fig10.png')
plt.show()
print(f"The r-value is: {rvalue}")
print("As city latitude gets closer to 0, cloudiness increases.")
# Out:
# The r-value is: -0.14224420645691882
# As city latitude gets closer to 0, cloudiness increases.

# %%
#Northern Hemisphere Latitude vs Cloudiness
plt.scatter(north_df['Latitude'],north_df['Wind Speed'])
plt.title("Northern Hemisphere - City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_df['Latitude'],north_df['Wind Speed'])
regress_values = north_df['Latitude'] * slope + intercept
plt.plot(north_df['Latitude'], regress_values, "r-")
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.annotate(line_eq, (-1,27))
plt.savefig('output_data/fig11.png')
plt.show()
print(f"The r-value is: {rvalue}")
print("As city latitude gets further from 0, wind speed decreases.")
# Out:
# The r-value is: 0.026090635912332148
# As city latitude gets further from 0, wind speed decreases.

# %%
#Southern Hemisphere Latitude vs Cloudiness
plt.scatter(south_df['Latitude'],south_df['Wind Speed'])
plt.title("Southern Hemisphere - City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_df['Latitude'],south_df['Wind Speed'])
regress_values = south_df['Latitude'] * slope + intercept
plt.plot(south_df['Latitude'], regress_values, "r-")
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.annotate(line_eq, (-25,27))
plt.savefig('output_data/fig12.png')
plt.show()
print(f"The r-value is: {rvalue}")
print("As city latitude gets closer to 0, wind speed decreases.")
# Out:
# The r-value is: -0.026099121930094525
# As city latitude gets closer to 0, wind speed decreases.
